# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt 

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import extract

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
# from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
# extract is a SQLalchemy function: see documentation here: https://docs.sqlalchemy.org/en/14/core/sqlelement.html
june_temps =session.query(Measurement).filter(extract('month', Measurement.date) == 6).all()

june_temps #returns sqlalchemy objects and we will convert them to a list
# Out:
# [<sqlalchemy.ext.automap.measurement at 0x252017baf88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809048>,
#  <sqlalchemy.ext.automap.measurement at 0x252018090c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809148>,
#  <sqlalchemy.ext.automap.measurement at 0x252018091c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809308>,
#  <sqlalchemy.ext.automap.measurement at 0x252018093c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809508>,
#  <sqlalchemy.ext.automap.measurement at 0x252018095c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809808>,
#  <sqlalchemy.ext.automap.measurement at 0x252018098c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018099c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201809fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f108>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f208>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f308>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f408>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f508>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f608>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f708>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f808>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180f908>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180fa08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180fb08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180fc08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180fd08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180fe08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520180ff08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201815f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181b988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181ba88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181bb88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181bc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181bd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181be88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520181bf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018210c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018211c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018212c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018213c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018214c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018215c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018216c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018217c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018218c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018219c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201821fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201826f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182d948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182da48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182db48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182dc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182dd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182de48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520182df48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832388>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832588>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832888>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832988>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201832f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018390c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018391c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018392c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018393c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018394c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018395c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018396c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018397c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018398c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018399c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201839fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f108>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f208>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f308>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f408>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f508>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f608>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f708>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f808>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183f908>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183fa08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183fb08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183fc08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183fd08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183fe08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520183ff08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201845f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184c988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184ca88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184cb88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184cc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184cd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184ce88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520184cf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018510c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018511c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018512c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018513c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018514c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018515c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018516c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018517c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018518c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018519c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201851fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201856f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185c948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185ca48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185cb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185cc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185cd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185ce48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520185cf48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863388>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863588>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863888>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863988>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201863f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186a9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186aac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186abc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186acc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186adc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186aec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186afc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f108>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f208>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f308>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f408>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f508>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f608>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f708>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f808>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186f908>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186fa08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186fb08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186fc08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186fd08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186fe08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520186ff08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201875f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187b988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187ba88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187bb88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187bc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187bd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187be88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520187bf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018820c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018821c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018822c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018823c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018824c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018825c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018826c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018827c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018828c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018829c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201882fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201886f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188d948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188da48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188db48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188dc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188dd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188de48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520188df48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893388>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893588>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893888>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893988>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201893f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189a9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189aac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189abc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189acc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189adc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189aec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520189afc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0108>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0208>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0308>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0408>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0508>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0608>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0708>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0808>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0908>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0b08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0c08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a0f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5048>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5148>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5248>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5348>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5448>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5548>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5648>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5748>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5848>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5948>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018a5f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac088>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac188>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac288>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac388>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac488>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac588>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac688>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac788>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac888>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ac988>,
#  <sqlalchemy.ext.automap.measurement at 0x252018aca88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018acb88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018acc88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018acd88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ace88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018acf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b10c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b11c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b12c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b13c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b14c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b15c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b16c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b17c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b18c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b19c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b1fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7108>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7208>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7308>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7408>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7508>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7608>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7708>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7808>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7908>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7b08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7c08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018b7f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be048>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be148>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be248>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be348>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be448>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be548>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be648>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be748>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be848>,
#  <sqlalchemy.ext.automap.measurement at 0x252018be948>,
#  <sqlalchemy.ext.automap.measurement at 0x252018bea48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018beb48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018bec48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018bed48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018bee48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018bef48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3088>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3188>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3288>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3388>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3488>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3588>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3688>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3788>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3888>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3988>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3a88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3b88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3c88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3d88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3e88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c3f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c90c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c91c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c92c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c93c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c94c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c95c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c96c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c97c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c98c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c99c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018c9fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf108>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf208>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf308>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf408>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf508>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf608>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf708>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf808>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cf908>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cfa08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cfb08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cfc08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cfd08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cfe08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018cff08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6048>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6148>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6248>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6348>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6448>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6548>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6648>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6748>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6848>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6948>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018d6f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd088>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd188>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd288>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd388>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd488>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd588>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd688>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd788>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd888>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dd988>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dda88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ddb88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ddc88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ddd88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018dde88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ddf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e20c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e21c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e22c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e23c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e24c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e25c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e26c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e27c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e28c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e29c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e2fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7108>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7208>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7308>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7408>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7508>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7608>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7708>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7808>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7908>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7b08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7c08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018e7f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee048>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee148>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee248>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee348>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee448>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee548>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee648>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee748>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee848>,
#  <sqlalchemy.ext.automap.measurement at 0x252018ee948>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eea48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eeb48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eec48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eed48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eee48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018eef48>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4088>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4188>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4288>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4388>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4488>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4588>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4688>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4788>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4888>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4988>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4a88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4b88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4c88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4d88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4e88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f4f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f90c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f91c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f92c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f93c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f94c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f95c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f96c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f97c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f98c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f99c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252018f9fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201900f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201906f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190d988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190da88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190db88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190dc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190dd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190de88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520190df88>,
#  <sqlalchemy.ext.automap.measurement at 0x252019130c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019131c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019132c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019133c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019134c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019135c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019136c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019137c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019138c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019139c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201913fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201917f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191e948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191ea48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191eb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191ec48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191ed48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191ee48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520191ef48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923388>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923588>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923888>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923988>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201923f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192a9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192aac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192abc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192acc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192adc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192aec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520192afc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201931f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201936f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193d988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193da88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193db88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193dc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193dd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193de88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520193df88>,
#  <sqlalchemy.ext.automap.measurement at 0x252019420c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019421c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019422c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019423c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019424c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019425c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019426c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019427c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019428c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019429c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201942fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201948f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194e948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194ea48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194eb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194ec48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194ed48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194ee48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520194ef48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954288>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954388>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954588>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954688>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954888>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954988>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201954f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195a9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195aac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195abc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195acc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195adc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195aec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520195afc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201961f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967048>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967148>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967348>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967448>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967648>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967748>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967948>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201967f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196c988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196ca88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196cb88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196cc88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196cd88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196ce88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520196cf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252019730c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019731c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019732c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019733c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019734c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019735c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019736c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019737c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019738c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252019739c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201973fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977108>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977208>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977408>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977508>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977708>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977808>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201977f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197f948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197fa48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197fb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197fc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197fd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197fe48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520197ff48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201985088>,
#  <sqlalchemy.ext.automap.measurement at 0x25201985188>,
#  ...]

# %%
#  3. Convert the June temperatures to a list.

# june_temps = {date:tobs for date,tobs in june_results}

june_temps_list = [temp.tobs for temp in june_temps] # for each SQLalchemy object, add the attribute tobs to the list.

print(june_temps_list)
# Out:
# [78.0, 76.0, 78.0, 76.0, 77.0, 78.0, 77.0, 78.0, 78.0, 79.0, 78.0, 78.0, 78.0, 77.0, 78.0, 78.0, 77.0, 77.0, 82.0, 78.0, 78.0, 78.0, 78.0, 78.0, 77.0, 76.0, 78.0, 78.0, 78.0, 78.0, 77.0, 78.0, 73.0, 70.0, 76.0, 77.0, 77.0, 77.0, 77.0, 78.0, 77.0, 77.0, 78.0, 78.0, 77.0, 78.0, 78.0, 75.0, 76.0, 76.0, 77.0, 78.0, 76.0, 77.0, 75.0, 77.0, 76.0, 76.0, 75.0, 77.0, 77.0, 76.0, 78.0, 77.0, 76.0, 77.0, 76.0, 76.0, 77.0, 77.0, 78.0, 77.0, 77.0, 77.0, 76.0, 75.0, 76.0, 76.0, 77.0, 76.0, 73.0, 73.0, 75.0, 77.0, 76.0, 77.0, 79.0, 78.0, 79.0, 78.0, 78.0, 79.0, 77.0, 77.0, 77.0, 77.0, 77.0, 78.0, 77.0, 76.0, 78.0, 78.0, 77.0, 78.0, 78.0, 73.0, 76.0, 77.0, 75.0, 76.0, 74.0, 75.0, 77.0, 76.0, 77.0, 78.0, 79.0, 77.0, 78.0, 79.0, 78.0, 78.0, 78.0, 78.0, 79.0, 79.0, 82.0, 80.0, 79.0, 79.0, 78.0, 78.0, 77.0, 78.0, 78.0, 73.0, 75.0, 75.0, 76.0, 84.0, 79.0, 76.0, 79.0, 79.0, 77.0, 79.0, 78.0, 78.0, 79.0, 77.0, 79.0, 78.0, 78.0, 78.0, 79.0, 77.0, 78.0, 78.0, 78.0, 78.0, 79.0, 79.0, 77.0, 78.0, 78.0, 78.0, 79.0, 79.0, 77.0, 79.0, 79.0, 79.0, 81.0, 76.0, 80.0, 78.0, 76.0, 71.0, 71.0, 74.0, 76.0, 78.0, 77.0, 77.0, 73.0, 77.0, 78.0, 78.0, 80.0, 79.0, 78.0, 77.0, 76.0, 77.0, 77.0, 78.0, 80.0, 79.0, 79.0, 77.0, 78.0, 79.0, 80.0, 76.0, 79.0, 80.0, 79.0, 79.0, 79.0, 79.0, 80.0, 79.0, 79.0, 80.0, 80.0, 77.0, 79.0, 83.0, 80.0, 80.0, 78.0, 79.0, 80.0, 77.0, 80.0, 78.0, 79.0, 80.0, 78.0, 80.0, 80.0, 81.0, 80.0, 79.0, 79.0, 75.0, 74.0, 76.0, 75.0, 75.0, 74.0, 75.0, 75.0, 75.0, 75.0, 75.0, 83.0, 75.0, 76.0, 73.0, 74.0, 74.0, 75.0, 70.0, 74.0, 75.0, 75.0, 75.0, 75.0, 75.0, 74.0, 72.0, 76.0, 73.0, 75.0, 76.0, 74.0, 75.0, 71.0, 69.0, 69.0, 74.0, 71.0, 74.0, 74.0, 75.0, 73.0, 73.0, 73.0, 75.0, 75.0, 74.0, 74.0, 75.0, 74.0, 73.0, 72.0, 74.0, 72.0, 75.0, 76.0, 74.0, 74.0, 74.0, 74.0, 74.0, 71.0, 71.0, 75.0, 72.0, 72.0, 73.0, 73.0, 73.0, 74.0, 73.0, 72.0, 72.0, 70.0, 72.0, 72.0, 72.0, 74.0, 73.0, 73.0, 70.0, 73.0, 72.0, 73.0, 69.0, 72.0, 71.0, 71.0, 73.0, 73.0, 72.0, 75.0, 75.0, 75.0, 75.0, 74.0, 74.0, 74.0, 75.0, 75.0, 74.0, 75.0, 75.0, 74.0, 72.0, 74.0, 74.0, 74.0, 74.0, 74.0, 72.0, 70.0, 75.0, 74.0, 71.0, 71.0, 70.0, 73.0, 71.0, 71.0, 77.0, 77.0, 74.0, 73.0, 75.0, 75.0, 74.0, 74.0, 75.0, 75.0, 72.0, 74.0, 76.0, 76.0, 75.0, 75.0, 74.0, 72.0, 74.0, 75.0, 70.0, 71.0, 72.0, 71.0, 73.0, 74.0, 72.0, 74.0, 76.0, 72.0, 75.0, 75.0, 72.0, 70.0, 76.0, 78.0, 72.0, 74.0, 74.0, 72.0, 71.0, 79.0, 79.0, 76.0, 75.0, 72.0, 74.0, 76.0, 76.0, 77.0, 75.0, 76.0, 75.0, 75.0, 76.0, 76.0, 74.0, 70.0, 69.0, 70.0, 68.0, 70.0, 74.0, 75.0, 74.0, 71.0, 73.0, 75.0, 74.0, 76.0, 76.0, 76.0, 76.0, 75.0, 75.0, 75.0, 74.0, 73.0, 76.0, 74.0, 78.0, 71.0, 75.0, 75.0, 74.0, 77.0, 77.0, 76.0, 76.0, 76.0, 78.0, 76.0, 75.0, 75.0, 76.0, 78.0, 75.0, 73.0, 76.0, 76.0, 76.0, 77.0, 76.0, 77.0, 72.0, 77.0, 75.0, 82.0, 77.0, 76.0, 74.0, 73.0, 77.0, 77.0, 77.0, 76.0, 74.0, 73.0, 72.0, 74.0, 73.0, 72.0, 75.0, 74.0, 75.0, 73.0, 75.0, 76.0, 74.0, 74.0, 73.0, 73.0, 76.0, 75.0, 70.0, 75.0, 73.0, 74.0, 74.0, 74.0, 74.0, 70.0, 75.0, 74.0, 73.0, 74.0, 72.0, 73.0, 67.0, 69.0, 76.0, 73.0, 70.0, 72.0, 74.0, 72.0, 72.0, 75.0, 73.0, 73.0, 72.0, 74.0, 76.0, 72.0, 74.0, 70.0, 74.0, 74.0, 74.0, 71.0, 75.0, 75.0, 76.0, 77.0, 75.0, 74.0, 75.0, 76.0, 78.0, 78.0, 76.0, 78.0, 76.0, 76.0, 78.0, 79.0, 77.0, 76.0, 77.0, 77.0, 76.0, 78.0, 76.0, 76.0, 77.0, 71.0, 74.0, 72.0, 77.0, 77.0, 78.0, 77.0, 77.0, 76.0, 75.0, 79.0, 75.0, 73.0, 76.0, 78.0, 77.0, 78.0, 76.0, 75.0, 76.0, 77.0, 74.0, 78.0, 77.0, 77.0, 74.0, 74.0, 78.0, 79.0, 79.0, 78.0, 75.0, 76.0, 78.0, 78.0, 74.0, 78.0, 77.0, 76.0, 78.0, 78.0, 78.0, 78.0, 74.0, 79.0, 77.0, 73.0, 79.0, 79.0, 78.0, 77.0, 78.0, 78.0, 80.0, 80.0, 79.0, 74.0, 71.0, 74.0, 75.0, 75.0, 74.0, 76.0, 75.0, 77.0, 77.0, 79.0, 79.0, 78.0, 79.0, 73.0, 78.0, 79.0, 80.0, 76.0, 79.0, 79.0, 77.0, 80.0, 79.0, 78.0, 78.0, 79.0, 78.0, 81.0, 78.0, 80.0, 79.0, 81.0, 80.0, 81.0, 79.0, 81.0, 78.0, 79.0, 79.0, 75.0, 79.0, 78.0, 80.0, 78.0, 77.0, 78.0, 79.0, 76.0, 80.0, 76.0, 81.0, 77.0, 76.0, 77.0, 75.0, 76.0, 79.0, 79.0, 77.0, 76. ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 

june_temps_df = pd.DataFrame(june_temps_list, columns = ["June Temps"])

june_temps_df
# Out:
#       June Temps
# 0           78.0
# 1           76.0
# 2           78.0
# 3           76.0
# 4           77.0
# ...          ...
# 1695        79.0
# 1696        74.0
# 1697        74.0
# 1698        76.0
# 1699        75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.

june_temps_df.describe()
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
# extract function arguments: sqlalchemy.sql.expression.extract(field, expr, **kwargs)¶
dec_temps = session.query(Measurement).filter(extract('month', Measurement.date) == 12).all()
#do not forget to include all() method to return all sqlalchemy objects 
dec_temps
# Out:
# [<sqlalchemy.ext.automap.measurement at 0x25201c76d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c76e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c76f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c76fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f740c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f743c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f746c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f749c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201f74fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201bf7fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d188>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d248>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d308>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d488>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d548>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d608>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d788>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d848>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d908>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0d9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0da88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0db48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0dc08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0dcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0dd88>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0de48>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0df08>,
#  <sqlalchemy.ext.automap.measurement at 0x25201c0dfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b6c0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b6c188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b6c248>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5e908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5e9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ea88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5eb48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ec08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ecc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ed88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ee48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5ef08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203b5efc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef248>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef548>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef848>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203bef9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befa88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befb48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befc08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befd88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203befe48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203beff08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249e788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249e848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249e908>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249e9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ea88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249eb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ec08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ecc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ed88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ee48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249ef08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520249efc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024710c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471188>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471248>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471308>,
#  <sqlalchemy.ext.automap.measurement at 0x252024713c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471488>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471548>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471608>,
#  <sqlalchemy.ext.automap.measurement at 0x252024716c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471788>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471848>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471908>,
#  <sqlalchemy.ext.automap.measurement at 0x252024719c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202471e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26548>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a266c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26848>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a269c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a26fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d248>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d548>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d848>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2d9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2da88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2db48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a2dc08>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd488>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd548>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd608>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd788>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd848>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd908>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cd9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cda88>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdb48>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdc08>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdd88>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cde48>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdf08>,
#  <sqlalchemy.ext.automap.measurement at 0x252021cdfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d40c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4188>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4248>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4308>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d43c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4488>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4548>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4608>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d46c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4788>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4848>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4908>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d49c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252021d4a88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520223ae48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520223af48>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240088>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240188>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240288>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240388>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240488>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240588>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240688>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240788>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240888>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240988>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202240f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252022440c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022441c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022442c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022443c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022444c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022445c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022446c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022447c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022448c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022449c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202244ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202244bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202244cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f0fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5108>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5208>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5308>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5408>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5508>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5608>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5708>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5808>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5908>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5b08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5c08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022f5f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa048>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa148>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa248>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa348>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa448>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa548>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa648>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa748>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa848>,
#  <sqlalchemy.ext.automap.measurement at 0x252022fa948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520235bec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520235bfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360108>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360208>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360308>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360408>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360508>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360608>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360708>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360808>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360908>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202360f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366048>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366148>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366248>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366348>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366448>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366548>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366648>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366748>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366848>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366948>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25202366d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0148>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0248>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0348>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0448>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0548>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0648>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0748>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0848>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0948>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d0f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6088>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6188>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6288>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6388>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6488>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6588>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6688>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6788>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6888>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6988>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6a88>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6b88>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6c88>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6d88>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6e88>,
#  <sqlalchemy.ext.automap.measurement at 0x252023d6f88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441288>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441388>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441488>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441588>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441688>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441788>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441888>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441988>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25202441f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252024460c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024461c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024462c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024463c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024464c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024465c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024466c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024467c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024468c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252024469c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25202446fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520244a108>,
#  <sqlalchemy.ext.automap.measurement at 0x252035000c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035001c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035002c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035003c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035004c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035005c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035006c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035007c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035008c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035009c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203500fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507108>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507208>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507408>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507508>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507708>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203507f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203566c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203566d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203566e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203566f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356c9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356cac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356cbc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356ccc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356cdc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356cec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520356cfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571108>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571208>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571408>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571508>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571708>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203571a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6848>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6948>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035a6f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac088>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac188>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac288>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac388>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac488>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac588>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac688>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac788>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac888>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ac988>,
#  <sqlalchemy.ext.automap.measurement at 0x252035aca88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035acb88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035acc88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035acd88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035ace88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035acf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b10c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b11c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b12c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b13c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b14c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b15c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252035b16c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363c948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363ca48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363cb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363cc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363cd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363ce48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520363cf48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643288>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643388>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643588>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643688>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203643f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036480c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036481c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036482c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036483c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036484c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036485c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036486c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203698d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203698e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203698f88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369d9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369dac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369dbc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369dcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369ddc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369dec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520369dfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2108>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2208>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2308>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2408>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2508>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2608>,
#  <sqlalchemy.ext.automap.measurement at 0x252036a2708>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ed588>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ed688>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ed788>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ed888>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ed988>,
#  <sqlalchemy.ext.automap.measurement at 0x252036eda88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036edb88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036edc88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036edd88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036ede88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036edf88>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f30c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f31c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f32c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f33c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f34c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f35c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f36c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f37c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252036f38c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203743f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252037490c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037491c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037492c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037493c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037494c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037495c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037496c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037497c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037498c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037499c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203749fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520374d108>,
#  <sqlalchemy.ext.automap.measurement at 0x2520374d208>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379d9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379dac8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379dbc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379dcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379ddc8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379dec8>,
#  <sqlalchemy.ext.automap.measurement at 0x2520379dfc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3108>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3208>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3308>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3408>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3508>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3608>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3708>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3808>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3908>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3a08>,
#  <sqlalchemy.ext.automap.measurement at 0x252037a3b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869408>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869508>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869708>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203869f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386d948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520386da48>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8688>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8788>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8888>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8988>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8a88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8b88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8c88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8d88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8e88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038c8f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ce9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ceac8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038cebc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038cecc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038cedc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038ceec8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038cefc8>,
#  <sqlalchemy.ext.automap.measurement at 0x252038d3108>,
#  <sqlalchemy.ext.automap.measurement at 0x252038d3208>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934288>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934388>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934588>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934688>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203934b88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520396ec48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520396ed48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520396ee48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520396ef48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972288>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972388>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972588>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972688>,
#  <sqlalchemy.ext.automap.measurement at 0x25203972788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203998f48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e088>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e188>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e288>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e388>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e488>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e588>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e688>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e788>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e888>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399e988>,
#  <sqlalchemy.ext.automap.measurement at 0x2520399ea88>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d4d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d4e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d4f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9048>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9148>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9248>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9348>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9448>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9548>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9648>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9748>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9848>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9948>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039d9f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252039df088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95408>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95508>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95708>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a95f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99048>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99148>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99248>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99348>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99448>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99548>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99648>,
#  <sqlalchemy.ext.automap.measurement at 0x25203a99748>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e09f88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e0e0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e0e1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e0e2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e0e3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e0e4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e44f48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49288>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49388>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49588>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49688>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e49f88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e500c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e501c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203e502c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf448>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf548>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf648>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf748>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf848>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaf948>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eafa48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eafb48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eafc48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eafd48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eafe48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eaff48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eb5088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eefa48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203eefb48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f00808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f00908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f00a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f00b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f70f48>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75088>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75188>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75288>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75388>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75488>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75588>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75688>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75788>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75888>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75988>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f75f88>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b0c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b1c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b2c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b3c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b4c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b5c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b6c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b7c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b8c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7b9c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7bac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7bbc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7bcc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203f7bdc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe60c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe61c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe62c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe63c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe64c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe65c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe66c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe67c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe68c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe69c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6ac8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6bc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6cc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6dc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6ec8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fe6fc8>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea108>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea208>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea308>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea408>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea508>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea608>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea708>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea808>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fea908>,
#  <sqlalchemy.ext.automap.measurement at 0x25203feaa08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203feab08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203feac08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203fead08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203feae08>,
#  <sqlalchemy.ext.automap.measurement at 0x25203feaf08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056508>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056608>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056708>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056808>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056908>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204056f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405a948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405aa48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405ab48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405ac48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405ad48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405ae48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520405af48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204060088>,
#  <sqlalchemy.ext.automap.measurement at 0x25204060188>,
#  <sqlalchemy.ext.automap.measurement at 0x25204060288>,
#  <sqlalchemy.ext.automap.measurement at 0x25204060388>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c0c08>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c0d08>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c0e08>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c0f08>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6048>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6148>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6248>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6348>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6448>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6548>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6648>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6748>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6848>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6948>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040c6f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb088>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb188>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb288>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb388>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb488>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb588>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb688>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb788>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb888>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cb988>,
#  <sqlalchemy.ext.automap.measurement at 0x252040cba88>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c408>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c508>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c608>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c708>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c808>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412c908>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412ca08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412cb08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412cc08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412cd08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412ce08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520412cf08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130048>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130148>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130248>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130348>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130448>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130548>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130648>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130748>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130848>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130948>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204130f48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204136088>,
#  <sqlalchemy.ext.automap.measurement at 0x25204136188>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196508>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196608>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196708>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196808>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196908>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204196f08>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c048>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c148>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c248>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c348>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c448>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c548>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c648>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c748>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c848>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419c948>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419ca48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419cb48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419cc48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419cd48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419ce48>,
#  <sqlalchemy.ext.automap.measurement at 0x2520419cf48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202308>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202408>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202508>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202608>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202708>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202808>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202908>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202a08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202b08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202c08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202d08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202e08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204202f08>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206048>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206148>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206248>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206348>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206448>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206548>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206648>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206748>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206848>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206948>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206a48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206b48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206c48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206d48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206e48>,
#  <sqlalchemy.ext.automap.measurement at 0x25204206f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042adc08>,
#  <sqlalchemy.ext.automap.measurement at 0x252042add08>,
#  <sqlalchemy.ext.automap.measurement at 0x252042ade08>,
#  <sqlalchemy.ext.automap.measurement at 0x252042adf08>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1048>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1148>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1248>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1348>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1448>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1548>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1648>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1748>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1848>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1948>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1a48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1b48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1c48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1d48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1e48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b1f48>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6088>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6188>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6288>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6388>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6488>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6588>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6688>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6788>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6888>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6988>,
#  <sqlalchemy.ext.automap.measurement at 0x252042b6a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323088>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323188>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323288>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323388>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323488>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323588>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323688>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323788>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323888>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323988>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323a88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323b88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323c88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323d88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323e88>,
#  <sqlalchemy.ext.automap.measurement at 0x25204323f88>,
#  <sqlalchemy.ext.automap.measurement at 0x252043280c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043281c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043282c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043283c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043284c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043285c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043286c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043287c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043288c8>,
#  <sqlalchemy.ext.automap.measurement at 0x252043289c8>,
#  <sqlalchemy.ext.automap.measurement at 0x25204328ac8>,
#  ...]

# %%
# 7. Convert the December temperatures to a list.
dec_temps_list = [temp.tobs for temp in dec_temps]
print(dec_temps_list)
# Out:
# [76.0, 74.0, 74.0, 64.0, 64.0, 67.0, 77.0, 66.0, 69.0, 68.0, 68.0, 71.0, 74.0, 67.0, 66.0, 69.0, 71.0, 70.0, 70.0, 74.0, 74.0, 71.0, 75.0, 75.0, 72.0, 69.0, 68.0, 73.0, 74.0, 73.0, 73.0, 73.0, 73.0, 71.0, 73.0, 73.0, 77.0, 72.0, 71.0, 73.0, 70.0, 73.0, 69.0, 74.0, 72.0, 71.0, 72.0, 72.0, 70.0, 73.0, 73.0, 72.0, 73.0, 73.0, 72.0, 63.0, 65.0, 71.0, 76.0, 70.0, 76.0, 69.0, 69.0, 69.0, 74.0, 76.0, 74.0, 73.0, 73.0, 74.0, 73.0, 73.0, 73.0, 74.0, 74.0, 71.0, 73.0, 72.0, 64.0, 66.0, 73.0, 72.0, 65.0, 64.0, 69.0, 68.0, 77.0, 71.0, 71.0, 69.0, 68.0, 68.0, 69.0, 70.0, 72.0, 76.0, 75.0, 69.0, 71.0, 71.0, 71.0, 68.0, 65.0, 70.0, 69.0, 69.0, 71.0, 67.0, 73.0, 74.0, 73.0, 67.0, 74.0, 75.0, 75.0, 74.0, 67.0, 73.0, 73.0, 71.0, 72.0, 71.0, 68.0, 65.0, 69.0, 70.0, 70.0, 74.0, 71.0, 74.0, 73.0, 72.0, 74.0, 72.0, 74.0, 75.0, 74.0, 70.0, 74.0, 70.0, 66.0, 61.0, 63.0, 63.0, 63.0, 63.0, 67.0, 56.0, 75.0, 77.0, 75.0, 75.0, 75.0, 75.0, 71.0, 70.0, 74.0, 74.0, 75.0, 72.0, 70.0, 66.0, 74.0, 75.0, 74.0, 75.0, 76.0, 74.0, 75.0, 74.0, 73.0, 68.0, 73.0, 74.0, 74.0, 77.0, 70.0, 70.0, 69.0, 75.0, 72.0, 69.0, 71.0, 68.0, 67.0, 69.0, 73.0, 70.0, 70.0, 70.0, 66.0, 67.0, 70.0, 66.0, 62.0, 71.0, 73.0, 69.0, 77.0, 74.0, 71.0, 72.0, 74.0, 74.0, 74.0, 74.0, 71.0, 73.0, 69.0, 66.0, 73.0, 72.0, 73.0, 74.0, 73.0, 66.0, 64.0, 66.0, 75.0, 65.0, 69.0, 71.0, 69.0, 78.0, 74.0, 68.0, 68.0, 70.0, 70.0, 71.0, 71.0, 71.0, 71.0, 69.0, 69.0, 72.0, 76.0, 72.0, 73.0, 73.0, 74.0, 69.0, 68.0, 74.0, 73.0, 73.0, 72.0, 71.0, 71.0, 68.0, 72.0, 71.0, 72.0, 71.0, 71.0, 72.0, 71.0, 71.0, 72.0, 72.0, 72.0, 69.0, 71.0, 71.0, 69.0, 74.0, 72.0, 71.0, 71.0, 72.0, 71.0, 67.0, 65.0, 70.0, 76.0, 68.0, 71.0, 71.0, 68.0, 70.0, 73.0, 73.0, 72.0, 71.0, 70.0, 72.0, 71.0, 72.0, 72.0, 71.0, 70.0, 71.0, 71.0, 71.0, 66.0, 65.0, 73.0, 72.0, 72.0, 65.0, 65.0, 68.0, 67.0, 76.0, 70.0, 71.0, 69.0, 67.0, 69.0, 71.0, 69.0, 72.0, 76.0, 75.0, 72.0, 75.0, 71.0, 69.0, 68.0, 68.0, 72.0, 70.0, 72.0, 75.0, 69.0, 72.0, 73.0, 73.0, 72.0, 73.0, 74.0, 73.0, 72.0, 68.0, 72.0, 71.0, 69.0, 67.0, 70.0, 72.0, 67.0, 67.0, 69.0, 67.0, 74.0, 70.0, 73.0, 71.0, 71.0, 71.0, 71.0, 72.0, 76.0, 78.0, 76.0, 73.0, 70.0, 68.0, 77.0, 66.0, 65.0, 69.0, 69.0, 66.0, 64.0, 74.0, 75.0, 80.0, 72.0, 73.0, 70.0, 69.0, 77.0, 74.0, 77.0, 72.0, 69.0, 69.0, 75.0, 75.0, 72.0, 73.0, 78.0, 75.0, 75.0, 74.0, 73.0, 70.0, 70.0, 72.0, 74.0, 74.0, 67.0, 74.0, 70.0, 73.0, 71.0, 71.0, 69.0, 68.0, 70.0, 71.0, 72.0, 70.0, 71.0, 72.0, 68.0, 68.0, 70.0, 70.0, 63.0, 71.0, 67.0, 69.0, 74.0, 72.0, 70.0, 69.0, 73.0, 74.0, 74.0, 73.0, 71.0, 72.0, 69.0, 71.0, 73.0, 73.0, 71.0, 72.0, 71.0, 64.0, 71.0, 62.0, 70.0, 64.0, 64.0, 70.0, 70.0, 69.0, 72.0, 68.0, 68.0, 65.0, 67.0, 68.0, 70.0, 67.0, 73.0, 70.0, 68.0, 72.0, 69.0, 71.0, 70.0, 75.0, 70.0, 68.0, 73.0, 71.0, 71.0, 70.0, 70.0, 70.0, 70.0, 72.0, 74.0, 71.0, 70.0, 70.0, 69.0, 71.0, 70.0, 70.0, 72.0, 72.0, 72.0, 72.0, 72.0, 70.0, 66.0, 71.0, 68.0, 79.0, 76.0, 73.0, 75.0, 71.0, 76.0, 74.0, 73.0, 73.0, 74.0, 73.0, 72.0, 76.0, 75.0, 77.0, 74.0, 76.0, 75.0, 76.0, 73.0, 75.0, 73.0, 73.0, 74.0, 78.0, 78.0, 78.0, 75.0, 75.0, 75.0, 74.0, 77.0, 72.0, 72.0, 73.0, 71.0, 75.0, 76.0, 74.0, 75.0, 74.0, 75.0, 73.0, 72.0, 72.0, 75.0, 74.0, 74.0, 72.0, 73.0, 70.0, 76.0, 78.0, 76.0, 78.0, 74.0, 71.0, 78.0, 70.0, 74.0, 74.0, 75.0, 76.0, 78.0, 72.0, 73.0, 76.0, 72.0, 72.0, 78.0, 76.0, 76.0, 77.0, 79.0, 73.0, 79.0, 77.0, 78.0, 76.0, 78.0, 77.0, 79.0, 75.0, 77.0, 76.0, 78.0, 78.0, 77.0, 78.0, 78.0, 76.0, 75.0, 72.0, 75.0, 77.0, 75.0, 77.0, 76.0, 76.0, 75.0, 72.0, 76.0, 75.0, 72.0, 72.0, 75.0, 69.0, 75.0, 74.0, 78.0, 77.0, 76.0, 72.0, 73.0, 74.0, 74.0, 74.0, 73.0, 73.0, 71.0, 72.0, 72.0, 75.0, 66.0, 66.0, 67.0, 76.0, 68.0, 69.0, 71.0, 70.0, 68.0, 66.0, 69.0, 69.0, 71.0, 72.0, 69.0, 72.0, 70.0, 76.0, 69.0, 71.0, 72.0, 71.0, 78.0, 73.0, 74.0, 68.0, 71.0, 76.0, 75.0, 74.0, 73.0, 73.0, 74.0, 69.0, 74.0, 72.0, 70.0, 67.0, 69.0, 73.0, 75.0, 74.0, 72.0, 71.0, 67.0, 74.0, 70.0, 70.0, 70.0, 71.0, 70.0, 71.0, 71.0, 68.0, 74.0, 75.0, 74.0, 77.0, 76.0, 77.0, 75. ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_temps_df = pd.DataFrame(dec_temps_list, columns = ["December Temps"])
dec_temps_df.head(10)
# Out:
#    December Temps
# 0            76.0
# 1            74.0
# 2            74.0
# 3            64.0
# 4            64.0
# 5            67.0
# 6            77.0
# 7            66.0
# 8            69.0
# 9            68.0

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_temps_df.describe()
# Out:
#        December Temps
# count     1517.000000
# mean        71.041529
# std          3.745920
# min         56.000000
# 25%         69.000000
# 50%         71.000000
# 75%         74.000000
# max         83.000000
